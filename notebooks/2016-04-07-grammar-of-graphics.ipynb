# %%
from bokeh.plotting import figure, show, output_notebook
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6dae812a-7ee2-403c-b6c0-e1e6e70a0de2">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Sanity Check
#
# Does it work? http://bokeh.pydata.org/en/latest/docs/user_guide/quickstart.html#userguide-quickstart

# %%
# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# output to static HTML file
# output_file("lines.html", title="line plot example")

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Temp.", line_width=15)

# show the results
show(p)
# Out:
#     <div class="plotdiv" id="f103180c-9236-4e20-96de-677b5718f9dc"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f103180c-9236-4e20-96de-677b5718f9dc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f103180c-9236-4e20-96de-677b5718f9dc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"23d83f3b-7b49-4dd6-83bb-961022c65b19":{"roots":{"references":[{"attributes":{"axis_label":"y","formatter":{"id":"91ea37ab-ad52-4dfc-b33a-47828977d6fb","type":"BasicTickFormatter"},"plot":{"id":"6c1bc4a7-e716-409e-88fc-7f33dd6baefc","subtype":"Figure","type":"Plot"},"ticker":{"id":"ce5f1d37-d1b2-46e3-ab8e-9299267567f8","type":"BasicTicker"}},"id":"28dc3c86-7e2c-4bf8-91b9-de25a562d966","type":"LinearAxis"},{"attributes":{},"id":"ce5f1d37-d1b2-46e3-ab8e-9299267567f8","type":"BasicTicker"},{"attributes":{"plot":{"id":"61d5a1ec-f00f-4a40-b53e-19432361a1bd","subtype":"Figure","type":"Plot"}},"id":"31557d81-0f6b-4457-b761-c1948b656386","type":"ResizeTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"415ad7e6-480e-4b76-9de5-5b91dea4ac8e","type":"ColumnDataSource"},{"attributes":{},"id":"d804aeb9-91b9-4a81-844d-0652be465604","type":"ToolEvents"},{"attributes":{"plot":{"id":"61d5a1ec-f00f-4a40-b53e-19432361a1bd","subtype":"Figure","type":"Plot"}},"id":"bf5522e0-9401-4bab-913a-620bf2a78b5c","type":"PreviewSaveTool"},{"attributes":{},"id":"8b3084ed-b24b-4515-82a1-5ecfdbbc6736","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"95127233-e492-47ef-9597-cb27b95cf499","type":"Line"},{"attributes":{"axis_label":"y","formatter":{"id":"dfc44fad-0b05-4686-9f31-517f56f6aff2","type":"BasicTickFormatter"},"plot":{"id":"ac44148c-7f58-43d5-b9eb-1d0e651401f7","subtype":"Figure","type":"Plot"},"ticker":{"id":"81d466ef-e932-41cd-aa70-6be81405f6cb","type":"BasicTicker"}},"id":"022b1cf8-4ef5-4372-bc63-21c100c5d775","type":"LinearAxis"},{"attributes":{"callback":null},"id":"073997b3-a815-4a99-be70-bf2ccd1db068","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"6c1bc4a7-e716-409e-88fc-7f33dd6baefc","subtype":"Figure","type":"Plot"},"ticker":{"id":"ce5f1d37-d1b2-46e3-ab8e-9299267567f8","type":"BasicTicker"}},"id":"19068f8e-14dc-42e1-a2ef-c43c3719dae4","type":"Grid"},{"attributes":{"callback":null},"id":"d2485b01-4505-4d9e-8fcd-f560ddef8179","type":"DataRange1d"},{"attributes":{"plot":{"id":"61d5a1ec-f00f-4a40-b53e-19432361a1bd","subtype":"Figure","type":"Plot"},"ticker":{"id":"e2b52f02-9a8c-4f43-87b4-7070ce62250f","type":"BasicTicker"}},"id":"7593153d-83dc-4da0-9cda-f9a4c04c46db","type":"Grid"},{"attributes":{"plot":{"id":"ac44148c-7f58-43d5-b9eb-1d0e651401f7","subtype":"Figure","type":"Plot"}},"id":"95369ba0-3588-446a-988f-6601361dd243","type":"ResetTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"be8c3634-1424-4f6d-907b-6b5c994ec155","type":"Line"},{"attributes":{},"id":"dfc44fad-0b05-4686-9f31-517f56f6aff2","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"e8694e0a-ad41-49a3-8034-0c2a84584323","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"285ea7c4-4266-4420-a1fb-828a99ade02a","type":"LinearAxis"}],"left":[{"id":"28dc3c86-7e2c-4bf8-91b9-de25a562d966","type":"LinearAxis"}],"renderers":[{"id":"285ea7c4-4266-4420-a1fb-828a99ade02a","type":"LinearAxis"},{"id":"6c36112a-e4c9-4605-b525-acf6b35127ea","type":"Grid"},{"id":"28dc3c86-7e2c-4bf8-91b9-de25a562d966","type":"LinearAxis"},{"id":"19068f8e-14dc-42e1-a2ef-c43c3719dae4","type":"Grid"},{"id":"1433e951-ff89-4ef4-a77f-eb3c653d500d","type":"BoxAnnotation"},{"id":"e4d4beeb-44ba-4506-b0b3-5837dd4eb225","type":"Legend"},{"id":"098601fc-f15c-4e1c-b63e-a7d6a51df39b","type":"GlyphRenderer"}],"title":"simple line example","tool_events":{"id":"246daaa9-6a4f-467d-bf7b-7b6e544000f6","type":"ToolEvents"},"tools":[{"id":"a7ec0635-9ee9-42b1-bc33-33c8c3f3b414","type":"PanTool"},{"id":"9b2cdca3-8320-40a0-a848-ef256a13d3c6","type":"WheelZoomTool"},{"id":"f07463a7-aa7f-48b7-b1c7-8e8b6969953d","type":"BoxZoomTool"},{"id":"a21a2174-d517-45d8-b ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[4]</strong>&gt;</code></p>

# %% [markdown]
# ## Grammar of Graphics
#
# > “the fundamental principles or rules of an art or science” (OED Online 1989). A good grammar will allow us to gain
# insight into the composition of complicated graphics, and reveal unexpected connections
# between seemingly different graphics (Cox 1978). A grammar provides a strong foundation
# for understanding a diverse range of graphics. A grammar may also help guide us on what
# a well-formed or correct graphic looks like, but there will still be many grammatically
# correct but nonsensical graphics.
# >
# > -- Wickham ([A Layered Grammar of Graphics](http://byrneslab.net/classes/biol607/readings/wickham_layered-grammar.pdf))
#
# ### Components
#
# [Visual index](http://ggplot.yhathq.com/docs/index.html) (Courtesy of yHat)
#
# * Layers
#     * data -> aesthetic mapping
#     * statistical transforms
#     * geometric objects (`geom`)
#     * position
#     * different "view" of the same data
# * Scales
# * Coordinate system
# * Faceting
#
# _can change each in relative isolation_

# %% [markdown]
#
# [![](http://r4ds.had.co.nz/images/visualization-grammar-3.png)](http://r4ds.had.co.nz/visualize.html)
# ([source](http://r4ds.had.co.nz/visualize.html))

# %% [markdown]
# ### Histogram: binning stat + bar geom
#
# ```r
# ggplot(data = diamonds, mapping = aes(price)) +
#     layer(geom = "bar", stat = "bin",
#     mapping = aes(y = ..count..))
# ```

# %% [markdown]
# ### In Python
# * http://bokeh.pydata.org/en/0.11.1/docs/gallery/histogram.html
# * http://bokeh.pydata.org/en/0.11.1/docs/gallery/histograms_chart.html

# %%
from bokeh.charts import Histogram
from bokeh.sampledata.autompg import autompg as df

df.sort('cyl', inplace=True)

hist = Histogram(df, values='hp', title="HP Distribution", legend='top_right')

show(hist)

# %%
import numpy as np
from bokeh.models import HoverTool, BoxSelectTool

TOOLS = [BoxSelectTool(), HoverTool()]

# create our canvas
p1 = figure(title="HP Distribution", background_fill_color="#E8DDCB", tools=TOOLS)

# stat
hist, edges = np.histogram(df.hp, density=True, bins=50)

# geom
p1.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")

show(p1)
# Out:
#     <div class="plotdiv" id="97b102e0-8b8e-4f51-9e43-a4d4e616a1b5"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("97b102e0-8b8e-4f51-9e43-a4d4e616a1b5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '97b102e0-8b8e-4f51-9e43-a4d4e616a1b5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f28df102-edce-46ab-a48d-d6336f0d2c8d":{"roots":{"references":[{"attributes":{"plot":{"id":"514e0796-2787-4e73-bcca-d1d872c6eb62","subtype":"Figure","type":"Plot"}},"id":"1a7be6b5-8d74-44bb-adf5-41f7b4031314","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"cyl":8}],"color":["#00ad9c"],"cyl":[8],"fill_alpha":[0.6],"height":[20.0],"line_alpha":[1.0],"line_color":["black"],"width":[14.049999999999997],"x":["139.0"],"y":[10.0]}},"id":"a20dd964-808b-48f7-983b-a0b81647ea3b","type":"ColumnDataSource"},{"attributes":{"legends":[["Temp.",[{"id":"53175956-93d5-41e1-b997-adf2339a99ed","type":"GlyphRenderer"}]]],"plot":{"id":"bbc5c791-b04f-495c-8a49-e5df7976a17f","subtype":"Figure","type":"Plot"}},"id":"22cc5c20-97c9-4d4e-b52d-527dd782d8e4","type":"Legend"},{"attributes":{"below":[{"id":"7c87fcad-29da-4eb4-8273-46d0af0307d9","type":"LinearAxis"}],"left":[{"id":"24b704c1-0b3a-4b06-8392-8ff17d28edab","type":"LinearAxis"}],"legend":"top_right","renderers":[{"id":"52755896-fdf1-4413-99dc-b2b4c10c4053","type":"BoxAnnotation"},{"id":"6ecd96ac-4fc5-404a-976d-c078a28c5185","type":"GlyphRenderer"},{"id":"9f6879e7-c33f-47ce-a60d-0cf651150322","type":"GlyphRenderer"},{"id":"c652a707-3493-4bd7-b7e7-88d166d87a6d","type":"GlyphRenderer"},{"id":"a51a5b14-bec2-4c7c-9a99-f9ef33a9a0fc","type":"GlyphRenderer"},{"id":"08dad285-3b07-4a66-9a25-0ceb0813b956","type":"GlyphRenderer"},{"id":"443eb9b3-d72b-4f73-92a0-a77e8c0215af","type":"GlyphRenderer"},{"id":"20461777-0e1a-41d9-83d1-c90c6a39654a","type":"GlyphRenderer"},{"id":"0d293668-6f1e-4edf-91ef-678ec2cd1375","type":"GlyphRenderer"},{"id":"0eb4852e-1085-46ab-ae31-28b68dffe213","type":"GlyphRenderer"},{"id":"fa83c61f-7609-4edb-8c35-437ee8588a86","type":"GlyphRenderer"},{"id":"fb6ea8bd-d75f-4c79-b2f0-9570a0213977","type":"GlyphRenderer"},{"id":"0b36d9d8-ebdd-4cf4-adca-6a8a2a2e23fc","type":"GlyphRenderer"},{"id":"aaa3c4c8-1b4b-48eb-aaeb-52e8b75cfc89","type":"GlyphRenderer"},{"id":"8c652eb0-0628-43f8-aa27-8c7485688c0d","type":"GlyphRenderer"},{"id":"3a0a1066-6033-460f-8775-b3e5bbf65523","type":"Legend"},{"id":"7c87fcad-29da-4eb4-8273-46d0af0307d9","type":"LinearAxis"},{"id":"24b704c1-0b3a-4b06-8392-8ff17d28edab","type":"LinearAxis"},{"id":"dd7d51ed-065a-4598-aeb1-d073e153fbdd","type":"Grid"}],"title":"HP Distribution","title_text_font_size":{"value":"14pt"},"tool_events":{"id":"310fc98e-b558-45bc-ad9a-6675912dcd16","type":"ToolEvents"},"tools":[{"id":"8c937492-0b81-4176-9630-3dae077097c9","type":"PanTool"},{"id":"d1d54636-c5f3-45f1-ab4a-f975ff4547e0","type":"WheelZoomTool"},{"id":"b40ca507-91bf-4b61-9a3b-2f3e405416ea","type":"BoxZoomTool"},{"id":"857449f9-16f8-46ef-a90e-21f605b48122","type":"PreviewSaveTool"},{"id":"13343ea2-9c22-481d-9df6-507667576198","type":"ResizeTool"},{"id":"baa83107-15ee-41d6-8b30-78344a51526e","type":"ResetTool"},{"id":"4fe54d80-b419-4c3c-b7b5-f67b3826aa1d","type":"HelpTool"}],"x_mapper_type":"auto","x_range":{"id":"78fc1aac-5f9a-4056-b8cb-7b731a6f8ad8","type":"Range1d"},"xgrid":false,"xscale":"auto","y_mapper_type":"auto","y_range":{"id":"fc22332f-894b-4d7d-a879-254d6075f5cb","type":"Range1d"},"yscale":"auto"},"id":"5b3cd32b-b142-4374-ba93-a4dbbde09050","subtype":"Chart","type":"Plot"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"1dc8662b-213f-4060-9991-5f990cadb928","type":"Line"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"81e0cb21-f438-49c7-a2d6-0b071e55e3a0","type":"Rect"},{"attributes":{},"id":"62acba4c-aa63-4cba-a393-2a4e2bed84b3","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightg ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[10]</strong>&gt;</code></p>

# %% [markdown]
# [Customizing Tooltips](http://bokeh.pydata.org/en/0.11.1/docs/user_guide/tools.html#setting-tool-visuals)

# %%
df.sort('cyl', inplace=True)

hist = Histogram(df, values='hp', color='cyl',
                 title="HP Distribution by Cylinder Count", legend='top_right')

show(hist)
# Out:
#     <div class="plotdiv" id="e5483eda-9037-42bc-841f-25686779a85f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e5483eda-9037-42bc-841f-25686779a85f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e5483eda-9037-42bc-841f-25686779a85f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1ab6bd17-18b7-49eb-9a87-142d3a84ed47":{"roots":{"references":[{"attributes":{"data_source":{"id":"8b569a20-457a-43c1-8316-21825460ea79","type":"ColumnDataSource"},"glyph":{"id":"caba462a-ec28-4ea6-85be-98a0121c6ed5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"45f377cc-621b-40d2-b661-d80c5295ffc9","type":"GlyphRenderer"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"15aedd6b-dc88-499f-be15-2ccbe7502b9f","type":"Quad"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#036564"},"left":{"field":"left"},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"0512722a-cecb-49f8-a7ef-e7f7906ba765","type":"Quad"},{"attributes":{"data_source":{"id":"cc4f0641-60a9-45fa-b3fa-f9b0a6e18f1a","type":"ColumnDataSource"},"glyph":{"id":"7783f049-38a9-4b87-b738-de84e8d7c8f6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c2327fe7-30df-400c-b83b-02af3f471e23","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"a192c431-7c0a-4092-8472-1429ddc86140","subtype":"Chart","type":"Plot"}},"id":"6eb8a980-fd38-40c2-83ed-65b94d745af9","type":"ResizeTool"},{"attributes":{"data_source":{"id":"6c8a6e33-1b58-4b1c-9d43-dc3257b801de","type":"ColumnDataSource"},"glyph":{"id":"eeee42c3-3e50-463c-96e9-89677bbc126d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0d293668-6f1e-4edf-91ef-678ec2cd1375","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c53925f0-29f4-4501-b984-fcc7fc82ed98","type":"ColumnDataSource"},"glyph":{"id":"e031d61e-ed8c-4337-84b7-ac9cfecb4470","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3e3ed2fb-da2e-495b-a233-ab77bc902839","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"514e0796-2787-4e73-bcca-d1d872c6eb62","subtype":"Figure","type":"Plot"}},"id":"1a7be6b5-8d74-44bb-adf5-41f7b4031314","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"cyl":6}],"color":["#df5320"],"cyl":[6],"fill_alpha":[0.6],"height":[5.0],"line_alpha":[1.0],"line_color":["black"],"width":[7.800000000000011],"x":["122.35"],"y":[2.5]}},"id":"50c03154-ee5a-40ef-a608-171ef7995688","type":"ColumnDataSource"},{"attributes":{"legends":[["Temp.",[{"id":"53175956-93d5-41e1-b997-adf2339a99ed","type":"GlyphRenderer"}]]],"plot":{"id":"bbc5c791-b04f-495c-8a49-e5df7976a17f","subtype":"Figure","type":"Plot"}},"id":"22cc5c20-97c9-4d4e-b52d-527dd782d8e4","type":"Legend"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"ae59da6f-d3ee-4e08-993c-d740e7ffafb8","type":"Line"},{"attributes":{"below":[{"id":"7c87fcad-29da-4eb4-8273-46d0af0307d9","type":"LinearAxis"}],"left":[{"id":"24b704c1-0b3a-4b06-8392-8ff17d28edab","type":"LinearAxis"}],"legend":"top_right","renderers":[{"id":"52755896-fdf1-4413-99dc-b2b4c10c4053","type":"BoxAnnotation"},{"id":"6ecd96ac-4fc5-404a-976d-c078a28c5185","type":"GlyphRenderer"},{"id":"9f6879e7-c33f-47ce-a60d-0cf651150322","type":"GlyphRenderer"},{"id":"c652a707-3493-4bd7-b7e7-88d166d87a6d","type":"GlyphRenderer"},{"id":"a51a5b14-bec2-4c7c-9a99-f9ef33a9a0fc","type":"GlyphRenderer"},{"id":"08dad285-3b07-4a66-9a25-0ceb0813b956","type":"GlyphRenderer"},{"id":"443eb9b3-d72b-4f73-92a0-a77e8c0215af","type":"GlyphRenderer"},{"id":"20461777-0e1a-41d9-83d1-c90c6a39654a","type":"GlyphRenderer"},{"id":"0d293668-6f1e-4edf-91ef-678ec2cd1375","type":"GlyphRenderer"},{"id":"0eb4852e-1085-46ab-ae31-28b68dffe213","type":"GlyphRenderer"},{"id":"fa83c61f-7609-4edb-8c35-437ee8588a86","type":"GlyphRenderer"},{"id":"fb6ea8bd-d75f-4c79-b2f0-9570a0213977","type":"GlyphRe ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[5]</strong>&gt;</code></p>

# %% [markdown]
# ### Coxcomb plot: bar chart + polar coordinates

# %% [markdown]
# ![](http://r4ds.had.co.nz/figures/visualize/unnamed-chunk-49-1.png)
# ![](http://r4ds.had.co.nz/figures/visualize/unnamed-chunk-49-2.png)
# ![](http://r4ds.had.co.nz/figures/visualize/unnamed-chunk-51-1.png)
# ![](http://r4ds.had.co.nz/figures/visualize/unnamed-chunk-53-1.png)
# ([source](http://r4ds.had.co.nz/visualize.html))
