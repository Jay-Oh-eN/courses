# %%
from bokeh.plotting import figure, show, output_notebook
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1fe82cff-798d-49c1-a921-e9305edced06">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Sanity Check
#
# Does it work? http://bokeh.pydata.org/en/latest/docs/user_guide/quickstart.html#userguide-quickstart

# %%
# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# output to static HTML file
# output_file("lines.html", title="line plot example")

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Temp.", line_width=2)

# show the results
show(p)
# Out:
#     <div class="plotdiv" id="b6d9eea9-ad6a-4650-8279-6e97f08409a4"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b6d9eea9-ad6a-4650-8279-6e97f08409a4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b6d9eea9-ad6a-4650-8279-6e97f08409a4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c39256c1-b868-4e92-9234-ca508586901e":{"roots":{"references":[{"attributes":{},"id":"91eda94f-5430-4fca-8f08-ba348b626297","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c5af533d-c2c8-40a5-8ee5-50f11d8e8018","type":"Line"},{"attributes":{"plot":{"id":"9bfeb5a5-d665-460a-9d44-07b5ee28b4e1","subtype":"Figure","type":"Plot"}},"id":"07bce77a-1ff7-49e1-ba71-71413fb61656","type":"ResizeTool"},{"attributes":{},"id":"cc335355-1ace-4ca2-b838-564bb681138c","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"9bfeb5a5-d665-460a-9d44-07b5ee28b4e1","subtype":"Figure","type":"Plot"}},"id":"4e26deda-cd6a-45d2-a378-05f747c36c30","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7e0eeee0-f0ed-4b33-981e-e78cf32d65c7","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"9bfeb5a5-d665-460a-9d44-07b5ee28b4e1","subtype":"Figure","type":"Plot"}},"id":"0c1d29a8-491c-4159-9a80-5ae49b23faa2","type":"ResetTool"},{"attributes":{"callback":null},"id":"4934e61a-e5a8-4e42-aad2-1b155e8db2de","type":"DataRange1d"},{"attributes":{},"id":"68371575-e37d-4ad5-a022-f446ccf8b377","type":"BasicTicker"},{"attributes":{"overlay":{"id":"7e0eeee0-f0ed-4b33-981e-e78cf32d65c7","type":"BoxAnnotation"},"plot":{"id":"9bfeb5a5-d665-460a-9d44-07b5ee28b4e1","subtype":"Figure","type":"Plot"}},"id":"2c6197a6-0cea-4405-9788-80eb04342a64","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"5cc98866-8e78-4029-a493-16ff2027dfc4","type":"ColumnDataSource"},{"attributes":{"legends":[["Temp.",[{"id":"f68e2052-10ee-443c-b400-59657eb9efec","type":"GlyphRenderer"}]]],"plot":{"id":"9bfeb5a5-d665-460a-9d44-07b5ee28b4e1","subtype":"Figure","type":"Plot"}},"id":"37de7cdf-f46e-4ecb-82eb-95021c14f9d7","type":"Legend"},{"attributes":{"axis_label":"y","formatter":{"id":"925f66cd-1b39-4f77-b4eb-bf67a8d3b7dc","type":"BasicTickFormatter"},"plot":{"id":"9bfeb5a5-d665-460a-9d44-07b5ee28b4e1","subtype":"Figure","type":"Plot"},"ticker":{"id":"68371575-e37d-4ad5-a022-f446ccf8b377","type":"BasicTicker"}},"id":"8f61a5c3-a6a3-4f22-b1fc-8c63a1466575","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"9bfeb5a5-d665-460a-9d44-07b5ee28b4e1","subtype":"Figure","type":"Plot"},"ticker":{"id":"68371575-e37d-4ad5-a022-f446ccf8b377","type":"BasicTicker"}},"id":"fb7dab62-7f47-4137-aaaa-83cb0e643e9b","type":"Grid"},{"attributes":{"axis_label":"x","formatter":{"id":"cc335355-1ace-4ca2-b838-564bb681138c","type":"BasicTickFormatter"},"plot":{"id":"9bfeb5a5-d665-460a-9d44-07b5ee28b4e1","subtype":"Figure","type":"Plot"},"ticker":{"id":"91eda94f-5430-4fca-8f08-ba348b626297","type":"BasicTicker"}},"id":"2dba6af8-ec70-4d81-a523-d6634c6e6e0d","type":"LinearAxis"},{"attributes":{"data_source":{"id":"5cc98866-8e78-4029-a493-16ff2027dfc4","type":"ColumnDataSource"},"glyph":{"id":"049fac18-63ce-4fd2-a64d-441ab2dffb5a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"c5af533d-c2c8-40a5-8ee5-50f11d8e8018","type":"Line"},"selection_glyph":null},"id":"f68e2052-10ee-443c-b400-59657eb9efec","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"7ef71682-199e-4df5-a9db-35830d353f88","type":"DataRange1d"},{"attributes":{"plot":{"id":"9bfeb5a5-d665-460a-9d44-07b5ee28b4e1","subtype":"Figure","type":"Plot"}},"id":"a4e90c42-6c63-4350-92c0-ad9c480772b8","type":"HelpTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"049fac18-63ce-4fd2-a64d-441ab2dffb5a","type":"Line"},{"attributes":{"plot":{"id":"9bfeb5a5-d665-460a-9d44-07b5ee28b4e1" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>

# %% [markdown]
# ## Grammar of Graphics
#
# > “the fundamental principles or rules of an art or science” (OED Online 1989). A good grammar will allow us to gain
# insight into the composition of complicated graphics, and reveal unexpected connections
# between seemingly different graphics (Cox 1978). A grammar provides a strong foundation
# for understanding a diverse range of graphics. A grammar may also help guide us on what
# a well-formed or correct graphic looks like, but there will still be many grammatically
# correct but nonsensical graphics.
# >
# > -- Wickham ([A Layered Grammar of Graphics](http://byrneslab.net/classes/biol607/readings/wickham_layered-grammar.pdf))
#
# ### Components
#
# [Visual index](http://ggplot.yhathq.com/docs/index.html) (Courtesy of yHat)
#
# * Layers
#     * data -> aesthetic mapping
#     * statistical transforms
#     * geometric objects (`geom`)
#     * position
#     * different "view" of the same data
# * Scales
# * Coordinate system
# * Faceting
#
# _can change each in relative isolation_

# %% [markdown]
#
# [![](http://r4ds.had.co.nz/images/visualization-grammar-3.png)](http://r4ds.had.co.nz/visualize.html)
# ([source](http://r4ds.had.co.nz/visualize.html))

# %% [markdown]
# ### Histogram: binning stat + bar geom
#
# ```r
# ggplot(data = diamonds, mapping = aes(price)) +
#     layer(geom = "bar", stat = "bin",
#     mapping = aes(y = ..count..))
# ```

# %% [markdown]
# ### In Python
# * http://bokeh.pydata.org/en/0.11.1/docs/gallery/histogram.html
# * http://bokeh.pydata.org/en/0.11.1/docs/gallery/histograms_chart.html

# %%
from bokeh.charts import Histogram
from bokeh.sampledata.autompg import autompg as df

df.sort('cyl', inplace=True)

hist = Histogram(df, values='hp', title="HP Distribution", legend='top_right')

show(hist)
# Out:
#     <div class="plotdiv" id="17b420ca-484f-482a-9807-7f02105f21af"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("17b420ca-484f-482a-9807-7f02105f21af");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '17b420ca-484f-482a-9807-7f02105f21af' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"31ae6b76-b4a9-42a2-81cb-2f85d89826fb":{"roots":{"references":[{"attributes":{"data_source":{"id":"e64a3523-f22c-4ed6-9f19-45d3d45274b9","type":"ColumnDataSource"},"glyph":{"id":"a1c4b024-0c08-4482-aab3-280ccf6b7e70","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"bdb47696-0176-4262-b0cd-52a9bf88aaa5","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d217f084-e2fc-4486-9a7a-d06be5dde5e1","type":"Rect"},{"attributes":{},"id":"91eda94f-5430-4fca-8f08-ba348b626297","type":"BasicTicker"},{"attributes":{"callback":null},"id":"485ef0d5-c789-4d57-ab69-fb64f5947d26","type":"DataRange1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"245295b7-63f1-4943-9633-7b48e0162431","type":"Rect"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c5af533d-c2c8-40a5-8ee5-50f11d8e8018","type":"Line"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"cyl":6}],"color":["#df5320"],"cyl":[6],"fill_alpha":[0.6],"height":[5.0],"line_alpha":[1.0],"line_color":["black"],"width":[7.800000000000011],"x":["122.35"],"y":[2.5]}},"id":"432ba62c-1fb8-4380-85cb-de2db99fc5ce","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"cyl":4}],"color":["#5ab738"],"cyl":[4],"fill_alpha":[0.6],"height":[5.0],"line_alpha":[1.0],"line_color":["black"],"width":[6.300000000000004],"x":["55.4"],"y":[2.5]}},"id":"37887af1-c15b-4b1b-b3ea-c04c13f3ed2c","type":"ColumnDataSource"},{"attributes":{"axis_label":"hp","formatter":{"id":"c8fd22d5-80bd-4cca-82a4-fc3a11fc7542","type":"BasicTickFormatter"},"plot":{"id":"9a3bae19-6cc1-48a2-8a19-f069602fadfa","subtype":"Chart","type":"Plot"},"ticker":{"id":"8f615e0d-1ae8-4b51-804c-13306579d3fa","type":"BasicTicker"}},"id":"9c99d606-9b83-4343-9b89-f3e4a4c27d37","type":"LinearAxis"},{"attributes":{"plot":{"id":"9a3bae19-6cc1-48a2-8a19-f069602fadfa","subtype":"Chart","type":"Plot"}},"id":"1172c9e8-b5fe-4476-9082-b8a8e11081e2","type":"ResizeTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[84.0],"line_alpha":[1.0],"line_color":["black"],"width":[13.25],"x":["92.0"],"y":[42.0]}},"id":"21dffaf9-69e9-488b-85a7-fd357c445d82","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"b4375fee-32ec-4ce8-ab6b-eb4a78fbeec8","type":"ColumnDataSource"},"glyph":{"id":"8f7d0cd0-1ada-4659-a303-93393c8e0cfa","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2c22bbf5-16d3-479d-8b9d-232b1d0fb2d7","type":"GlyphRenderer"},{"attributes":{},"id":"cd194d2c-267c-43bd-92a2-8c080e24ed94","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"50405d9b-038e-4ca4-856e-2504d431829a","type":"DataRange1d"},{"attributes":{"data_source":{"id":"89d9795c-fc19-4263-941f-2972095b87c6","type":"ColumnDataSource"},"glyph":{"id":"c703730a-fabd-4ba3-a62b-84e51f105989","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8976dbad-8cc7-4a66-a462-d25557c12c9c","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width", ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>

# %%
import numpy as np

p1 = figure(title="HP Distribution", background_fill_color="#E8DDCB")

# stat
hist, edges = np.histogram(df.hp, density=True, bins=50)

# geom
p1.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")

show(p1)
# Out:
#     <div class="plotdiv" id="15c68766-cdd6-47d4-bd7e-8a4ae61e8183"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("15c68766-cdd6-47d4-bd7e-8a4ae61e8183");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '15c68766-cdd6-47d4-bd7e-8a4ae61e8183' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1f3b245b-371b-4bb0-8d0b-cda2fc3607c7":{"roots":{"references":[{"attributes":{},"id":"91eda94f-5430-4fca-8f08-ba348b626297","type":"BasicTicker"},{"attributes":{"data_source":{"id":"170ab9b6-c551-4ca8-8e91-8006e82975b1","type":"ColumnDataSource"},"glyph":{"id":"e93fa2bd-b4d7-4fe8-985f-3eae7dae8845","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d67b8c07-cb9e-46ad-9499-534852f2761d","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"e8494f61-aeb3-4016-a05c-434ffbcc214b","subtype":"Figure","type":"Plot"}},"id":"c91931b7-5bc0-4602-9561-9abe86ae3383","type":"ResizeTool"},{"attributes":{"plot":{"id":"9bfeb5a5-d665-460a-9d44-07b5ee28b4e1","subtype":"Figure","type":"Plot"}},"id":"0c1d29a8-491c-4159-9a80-5ae49b23faa2","type":"ResetTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d3bc51ce-8514-4412-857c-371fee3b3bc9","type":"Rect"},{"attributes":{"plot":{"id":"e8494f61-aeb3-4016-a05c-434ffbcc214b","subtype":"Figure","type":"Plot"}},"id":"9d719724-ddc9-4314-b5fe-c6850fc7b5b6","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"dcd6b83b-d1b7-44a4-8a3a-da6d69c757c8","subtype":"Chart","type":"Plot"},"ticker":{"id":"60b6dedf-08ca-4f40-a253-3d5fbdb501af","type":"BasicTicker"}},"id":"1b5e59e9-c74c-4b22-82f6-bb73a4491771","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7e0eeee0-f0ed-4b33-981e-e78cf32d65c7","type":"BoxAnnotation"},{"attributes":{},"id":"7c312b1a-e880-40ce-bab9-ee7b26eb2bdf","type":"ToolEvents"},{"attributes":{},"id":"c7d6293f-2a8b-4fb4-a69b-9377d438a87d","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"cyl":6}],"color":["#df5320"],"cyl":[6],"fill_alpha":[0.6],"height":[0.0],"line_alpha":[1.0],"line_color":["black"],"width":[7.800000000000011],"x":["153.35"],"y":[0.0]}},"id":"a12e2c00-6761-4f9a-8509-038d17d206a9","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d4ec77f5-f0e4-43ab-8dd8-f86f96ad26fb","type":"ColumnDataSource"},"glyph":{"id":"687da6e2-df90-46e6-b2ca-1dae86a3c9a2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"fe3b78cd-8482-47a8-a3d5-757f4bc49f96","type":"GlyphRenderer"},{"attributes":{},"id":"548467cf-a23c-4540-9349-3868aa807692","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"9bfeb5a5-d665-460a-9d44-07b5ee28b4e1","subtype":"Figure","type":"Plot"},"ticker":{"id":"68371575-e37d-4ad5-a022-f446ccf8b377","type":"BasicTicker"}},"id":"fb7dab62-7f47-4137-aaaa-83cb0e643e9b","type":"Grid"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"cyl":6}],"color":["#df5320"],"cyl":[6],"fill_alpha":[0.6],"height":[23.0],"line_alpha":[1.0],"line_color":["black"],"width":[7.800000000000011],"x":["106.9"],"y":[11.5]}},"id":"7baa3260-9705-4442-bc01-dde37cb994c1","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"cyl":8}],"color":["#00ad9c"],"cyl":[8],"fill_alpha":[0.6],"height":[4.0],"line_alpha":[1.0],"line_color":["black"],"width":[14.049999999999997],"x":["111.0"],"y":[2.0]}},"id":"d4ec77f5-f0e4-43ab-8dd8-f86f96ad26fb","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"96e5b6d5-601f-4b02-9058-a0f707e4128a","type":"ColumnDataSource"},"glyph":{ ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[8]</strong>&gt;</code></p>

# %%
df.sort('cyl', inplace=True)

hist = Histogram(df, values='hp', color='cyl',
                 title="HP Distribution by Cylinder Count", legend='top_right')

show(hist)
# Out:
#     <div class="plotdiv" id="aacf5b64-a510-415d-aec0-b5fb46f92554"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aacf5b64-a510-415d-aec0-b5fb46f92554");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aacf5b64-a510-415d-aec0-b5fb46f92554' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1486bf27-864e-4e40-a9da-703da70c01af":{"roots":{"references":[{"attributes":{},"id":"91eda94f-5430-4fca-8f08-ba348b626297","type":"BasicTicker"},{"attributes":{"data_source":{"id":"170ab9b6-c551-4ca8-8e91-8006e82975b1","type":"ColumnDataSource"},"glyph":{"id":"e93fa2bd-b4d7-4fe8-985f-3eae7dae8845","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d67b8c07-cb9e-46ad-9499-534852f2761d","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"eaaa07c1-fd56-49c1-85b9-f43452b84955","type":"Rect"},{"attributes":{"plot":{"id":"e8494f61-aeb3-4016-a05c-434ffbcc214b","subtype":"Figure","type":"Plot"}},"id":"c91931b7-5bc0-4602-9561-9abe86ae3383","type":"ResizeTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"cyl":4}],"color":["#5ab738"],"cyl":[4],"fill_alpha":[0.6],"height":[5.0],"line_alpha":[1.0],"line_color":["black"],"width":[6.300000000000004],"x":["55.4"],"y":[2.5]}},"id":"37887af1-c15b-4b1b-b3ea-c04c13f3ed2c","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d3bc51ce-8514-4412-857c-371fee3b3bc9","type":"Rect"},{"attributes":{"plot":{"id":"e8494f61-aeb3-4016-a05c-434ffbcc214b","subtype":"Figure","type":"Plot"}},"id":"9d719724-ddc9-4314-b5fe-c6850fc7b5b6","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"dcd6b83b-d1b7-44a4-8a3a-da6d69c757c8","subtype":"Chart","type":"Plot"},"ticker":{"id":"60b6dedf-08ca-4f40-a253-3d5fbdb501af","type":"BasicTicker"}},"id":"1b5e59e9-c74c-4b22-82f6-bb73a4491771","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7e0eeee0-f0ed-4b33-981e-e78cf32d65c7","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1b5bb392-9393-4f03-a780-41f55cbd1941","type":"Rect"},{"attributes":{},"id":"7c312b1a-e880-40ce-bab9-ee7b26eb2bdf","type":"ToolEvents"},{"attributes":{},"id":"c7d6293f-2a8b-4fb4-a69b-9377d438a87d","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"61018136-ef92-4bc8-85c5-aa272fb3029d","subtype":"Chart","type":"Plot"}},"id":"c4e57ee6-ca90-49ea-a650-84d2575e35ef","type":"PreviewSaveTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x"],"data":{"chart_index":[{"cyl":6}],"color":["#df5320"],"cyl":[6],"fill_alpha":[0.6],"height":[0.0],"line_alpha":[1.0],"line_color":["black"],"width":[7.800000000000011],"x":["153.35"],"y":[0.0]}},"id":"69aa2909-7952-4f4d-9cc2-474bb03de7e6","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d4ec77f5-f0e4-43ab-8dd8-f86f96ad26fb","type":"ColumnDataSource"},"glyph":{"id":"687da6e2-df90-46e6-b2ca-1dae86a3c9a2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"fe3b78cd-8482-47a8-a3d5-757f4bc49f96","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"9573fe05-c6fe-4b27-9a54-4c2015e64d78","type":"BoxAnnotation"},"plot":{"id":"0289454f-265d-4bde-85b7-f82b42aa36e5","subtype":"Chart","type":"Plot"}},"id":"584a2971-8bfb-4ef0-9ed3-5df200878084","type":" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[10]</strong>&gt;</code></p>

# %% [markdown]
# ### Coxcomb plot: bar chart + polar coordinates

# %% [markdown]
# ![](http://r4ds.had.co.nz/figures/visualize/unnamed-chunk-49-1.png)
# ![](http://r4ds.had.co.nz/figures/visualize/unnamed-chunk-49-2.png)
# ![](http://r4ds.had.co.nz/figures/visualize/unnamed-chunk-51-1.png)
# ![](http://r4ds.had.co.nz/figures/visualize/unnamed-chunk-53-1.png)
# ([source](http://r4ds.had.co.nz/visualize.html))
